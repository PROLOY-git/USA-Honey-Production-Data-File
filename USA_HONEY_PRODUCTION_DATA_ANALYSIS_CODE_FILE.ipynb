# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('US_honey_dataset.csv')

# %%
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %%
# 1995-2021->27 years of data
# the above data provides for each state the prodiction in each year

# %%
# performing EDA
#checking with datatype
#data cleansing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1115 non-null   int64
#  1   state                1115 non-null   object
#  2   colonies_number      1115 non-null   int64
#  3   yield_per_colony     1115 non-null   int64
#  4   production           1115 non-null   int64
#  5   stocks               1115 non-null   int64
#  6   average_price        1115 non-null   float64
#  7   value_of_production  1115 non-null   int64
#  8   year                 1115 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 78.5+ KB

# %%
df=df.drop(["Unnamed: 0"],axis=1)

# %%
df
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# ...

# %%
#CHECK FOR NULL VALUESabs

df.isnull()
# Out:
#       state  colonies_number  yield_per_colony  production  stocks  \
# 0     False            False             False       False   False
# 1     False            False             False       False   False
# 2     False            False             False       False   False
# 3     False            False             False       False   False
# 4     False            False             False       False   False
# ...     ...              ...               ...         ...     ...
# 1110  False            False             False       False   False
# 1111  False            False             False       False   False
# 1112  False            False             False       False   False
# 1113  False            False             False       False   False
# 1114  False            False             False       False   False
#
#       average_price  value_of_production   year
# 0             False                False  False
# 1             False                False  False
# ...

# %%
#CHECK FOR NULL VALUESabs

df.isnull().sum()
# Out:
# state                  0
# colonies_number        0
# yield_per_colony       0
# production             0
# stocks                 0
# average_price          0
# value_of_production    0
# year                   0
# dtype: int64

# %%
#check for duplicates

df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1110    False
# 1111    False
# 1112    False
# 1113    False
# 1114    False
# Length: 1115, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# outliers

plt.boxplot(df["colonies_number"])
plt.show()

# %%
df.columns
# Out:
# Index(['state', 'colonies_number', 'yield_per_colony', 'production', 'stocks',
#        'average_price', 'value_of_production', 'year'],
#       dtype='object')

# %%
for col in df.columns:
    if df[col].dtype !="object":
        plt.boxplot(df[col])
        plt.title(col)
        plt.show()

# %%
#due to the data loss, we ar enot goinfg to remove the outiers

# %%
df
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# ...

# %% [markdown]
# # visual exploration

# %%
# Q1. which states are rarely participating for honey production since last 27 years?

# %%
df["state"].unique()
# Out:
# array(['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'NewJersey', 'NewMexico', 'NewYork',
#        'NorthCarolina', 'NorthDakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'SouthCarolina', 'SouthDakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'WestVirginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df["state"].nunique()
# Out:
# 44

# %%
df.groupby('state')["year"].count()
# Out:
# state
# Alabama          27
# Arizona          27
# Arkansas         27
# California       27
# Colorado         27
# Florida          27
# Georgia          27
# Hawaii           27
# Idaho            27
# Illinois         27
# Indiana          27
# Iowa             27
# Kansas           27
# Kentucky         26
# Louisiana        27
# Maine            27
# Maryland          9
# Michigan         27
# Minnesota        27
# Mississippi      27
# Missouri         27
# Montana          27
# Nebraska         27
# Nevada           15
# NewJersey        27
# NewMexico        18
# NewYork          27
# NorthCarolina    27
# NorthDakota      27
# Ohio             27
# Oklahoma          9
# Oregon           27
# Pennsylvania     27
# SouthCarolina    12
# SouthDakota      27
# Tennessee        27
# Texas            27
# Utah             27
# Vermont          27
# Virginia         27
# Washington       27
# WestVirginia     27
# Wisconsin        27
# Wyoming          27
# ...

# %%
ds=df["state"].value_counts()
ds
# Out:
# Alabama          27
# Missouri         27
# Arizona          27
# NewJersey        27
# NewYork          27
# NorthCarolina    27
# NorthDakota      27
# Ohio             27
# Oregon           27
# Pennsylvania     27
# SouthDakota      27
# Tennessee        27
# Texas            27
# Utah             27
# Vermont          27
# Virginia         27
# Washington       27
# WestVirginia     27
# Wisconsin        27
# Montana          27
# Nebraska         27
# Mississippi      27
# Minnesota        27
# Arkansas         27
# California       27
# Colorado         27
# Florida          27
# Georgia          27
# Hawaii           27
# Idaho            27
# Illinois         27
# Indiana          27
# Iowa             27
# Kansas           27
# Louisiana        27
# Maine            27
# Michigan         27
# Wyoming          27
# Kentucky         26
# NewMexico        18
# Nevada           15
# SouthCarolina    12
# Oklahoma          9
# Maryland          9
# Name: state, dtype: int64

# %%
#here maryland oklahoma have least participation for honey production

# %%
val=ds.values
val
# Out:
# array([27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27,
#        27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27,
#        27, 27, 27, 27, 26, 18, 15, 12,  9,  9], dtype=int64)

# %%
la=ds.index
la
# Out:
# Index(['Alabama', 'Missouri', 'Arizona', 'NewJersey', 'NewYork',
#        'NorthCarolina', 'NorthDakota', 'Ohio', 'Oregon', 'Pennsylvania',
#        'SouthDakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia',
#        'Washington', 'WestVirginia', 'Wisconsin', 'Montana', 'Nebraska',
#        'Mississippi', 'Minnesota', 'Arkansas', 'California', 'Colorado',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa',
#        'Kansas', 'Louisiana', 'Maine', 'Michigan', 'Wyoming', 'Kentucky',
#        'NewMexico', 'Nevada', 'SouthCarolina', 'Oklahoma', 'Maryland'],
#       dtype='object')

# %%
plt.pie(val)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(val,labels=la)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,10))
plt.pie(val,labels=la,autopct="%0.2f",textprops={'fontsize': 8},rotatelabels=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Q2. Which are the top 5 Honey producing state?

# %%
df
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# ...

# %%
df.groupby('state').sum()["production"]
# Out:
# state
# Alabama           14467000
# Arizona           38844000
# Arkansas          51846000
# California       423876000
# Colorado          32660000
# Florida          280934000
# Georgia           57426000
# Hawaii            15420000
# Idaho             87188000
# Illinois           9864000
# Indiana            9686000
# Iowa              48607000
# Kansas            14138000
# Kentucky           3224000
# Louisiana         60568000
# Maine              4762000
# Maryland           1975000
# Michigan         101063000
# Minnesota        176581000
# Mississippi       21235000
# Missouri          17904000
# Montana          197173000
# Nebraska          63655000
# Nevada             7399000
# NewJersey          6913000
# NewMexico         10082000
# NewYork           78444000
# NorthCarolina      8909000
# NorthDakota      513742000
# Ohio              22485000
# Oklahoma           2055000
# Oregon            43789000
# Pennsylvania      21370000
# SouthCarolina      2823000
# ...

# %%
df.groupby('state').sum()["production"].reset_index()
# Out:
#             state  production
# 0         Alabama    14467000
# 1         Arizona    38844000
# 2        Arkansas    51846000
# 3      California   423876000
# 4        Colorado    32660000
# 5         Florida   280934000
# 6         Georgia    57426000
# 7          Hawaii    15420000
# 8           Idaho    87188000
# 9        Illinois     9864000
# 10        Indiana     9686000
# 11           Iowa    48607000
# 12         Kansas    14138000
# 13       Kentucky     3224000
# 14      Louisiana    60568000
# 15          Maine     4762000
# 16       Maryland     1975000
# 17       Michigan   101063000
# 18      Minnesota   176581000
# 19    Mississippi    21235000
# 20       Missouri    17904000
# 21        Montana   197173000
# 22       Nebraska    63655000
# 23         Nevada     7399000
# 24      NewJersey     6913000
# 25      NewMexico    10082000
# 26        NewYork    78444000
# 27  NorthCarolina     8909000
# 28    NorthDakota   513742000
# 29           Ohio    22485000
# ...

# %%
new_df=df.groupby("state").sum()['production'].reset_index()

# %%
new_df
# Out:
#             state  production
# 0         Alabama    14467000
# 1         Arizona    38844000
# 2        Arkansas    51846000
# 3      California   423876000
# 4        Colorado    32660000
# 5         Florida   280934000
# 6         Georgia    57426000
# 7          Hawaii    15420000
# 8           Idaho    87188000
# 9        Illinois     9864000
# 10        Indiana     9686000
# 11           Iowa    48607000
# 12         Kansas    14138000
# 13       Kentucky     3224000
# 14      Louisiana    60568000
# 15          Maine     4762000
# 16       Maryland     1975000
# 17       Michigan   101063000
# 18      Minnesota   176581000
# 19    Mississippi    21235000
# 20       Missouri    17904000
# 21        Montana   197173000
# 22       Nebraska    63655000
# 23         Nevada     7399000
# 24      NewJersey     6913000
# 25      NewMexico    10082000
# 26        NewYork    78444000
# 27  NorthCarolina     8909000
# 28    NorthDakota   513742000
# 29           Ohio    22485000
# ...

# %%
new_df=new_df.sort_values(by=['production'],ascending=False)
new_df
# Out:
#             state  production
# 28    NorthDakota   513742000
# 3      California   423876000
# 34    SouthDakota   355726000
# 5         Florida   280934000
# 21        Montana   197173000
# 18      Minnesota   176581000
# 36          Texas   129441000
# 17       Michigan   101063000
# 42      Wisconsin    99909000
# 8           Idaho    87188000
# 26        NewYork    78444000
# 22       Nebraska    63655000
# 14      Louisiana    60568000
# 6         Georgia    57426000
# 40     Washington    53238000
# 2        Arkansas    51846000
# 11           Iowa    48607000
# 43        Wyoming    43921000
# 31         Oregon    43789000
# 1         Arizona    38844000
# 4        Colorado    32660000
# 29           Ohio    22485000
# 32   Pennsylvania    21370000
# 19    Mississippi    21235000
# 37           Utah    20369000
# 20       Missouri    17904000
# 7          Hawaii    15420000
# 0         Alabama    14467000
# 12         Kansas    14138000
# 25      NewMexico    10082000
# ...

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=new_df,x="state",y="production")
plt.xticks(rotation=90)
plt.show()

# %%
x=new_df.head()
x
# Out:
#           state  production
# 28  NorthDakota   513742000
# 3    California   423876000
# 34  SouthDakota   355726000
# 5       Florida   280934000
# 21      Montana   197173000

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=x,x="state",y="production")
plt.xticks(rotation=90)
plt.show()

# %%
#northdakota,california,southdakota,florida,montana are top 5 honey producing state

# %% [markdown]
# # 3.What is the Change in mean Average price of Honey

# %%
df.groupby('year')["average_price"].mean()
# Out:
# year
# 1995     74.840909
# 1996     99.568182
# 1997     91.325581
# 1998     83.720930
# 1999     80.325581
# 2000     79.023256
# 2001     88.465116
# 2002    133.204545
# 2003    151.068182
# 2004    132.350000
# 2005    116.341463
# 2006    134.341463
# 2007    140.170732
# 2008    160.878049
# 2009    176.195122
# 2010    192.900000
# 2011    216.725000
# 2012    236.700000
# 2013    260.717949
# 2014    282.025000
# 2015    292.625000
# 2016    291.925000
# 2017    302.775000
# 2018      3.083500
# 2019      2.925500
# 2020      3.050000
# 2021      3.334250
# Name: average_price, dtype: float64

# %%
new_df=df.groupby("year")["average_price"].mean().reset_index()

# %%
new_df
# Out:
#     year  average_price
# 0   1995      74.840909
# 1   1996      99.568182
# 2   1997      91.325581
# 3   1998      83.720930
# 4   1999      80.325581
# 5   2000      79.023256
# 6   2001      88.465116
# 7   2002     133.204545
# 8   2003     151.068182
# 9   2004     132.350000
# 10  2005     116.341463
# 11  2006     134.341463
# 12  2007     140.170732
# 13  2008     160.878049
# 14  2009     176.195122
# 15  2010     192.900000
# 16  2011     216.725000
# 17  2012     236.700000
# 18  2013     260.717949
# 19  2014     282.025000
# 20  2015     292.625000
# 21  2016     291.925000
# 22  2017     302.775000
# 23  2018       3.083500
# 24  2019       2.925500
# 25  2020       3.050000
# 26  2021       3.334250

# %%
plt.figure(figsize=(15,4))
sns.lineplot(data=new_df,x='year',y="average_price")
plt.show()
plt.figure(figsize=(15,4))
sns.barplot(data=new_df,x='year',y="average_price")
plt.show()

# %%
#1995-2017 the avg price of honey is inc in a good manner but we ca observer a udden drop in the avg price after 2017 and after
#it is constant

# %% [markdown]
# # Which was the year when production of Honey in whole US was the highest?

# %%
df.groupby('year')['production'].sum()
# Out:
# year
# 1995    210272000
# 1996    197995000
# 1997    191176000
# 1998    219321000
# 1999    204585000
# 2000    220320000
# 2001    185403000
# 2002    170732000
# 2003    180741000
# 2004    182379000
# 2005    173857000
# 2006    154120000
# 2007    147609000
# 2008    160096000
# 2009    143340000
# 2010     44797000
# 2011     36550000
# 2012     31662000
# 2013     37974000
# 2014     40990000
# 2015     41832000
# 2016     40837000
# 2017     30478000
# 2018     28989000
# 2019     40510000
# 2020     39412000
# 2021     23187000
# Name: production, dtype: int64

# %%
highest_production=df.groupby('year')['production'].sum()

# %%
highest_production
# Out:
# year
# 1995    210272000
# 1996    197995000
# 1997    191176000
# 1998    219321000
# 1999    204585000
# 2000    220320000
# 2001    185403000
# 2002    170732000
# 2003    180741000
# 2004    182379000
# 2005    173857000
# 2006    154120000
# 2007    147609000
# 2008    160096000
# 2009    143340000
# 2010     44797000
# 2011     36550000
# 2012     31662000
# 2013     37974000
# 2014     40990000
# 2015     41832000
# 2016     40837000
# 2017     30478000
# 2018     28989000
# 2019     40510000
# 2020     39412000
# 2021     23187000
# Name: production, dtype: int64

# %%
highest_production=highest_production.sort_values(ascending=False).reset_index()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=highest_production.year,y=highest_production.production)
plt.xticks(rotation='vertical')
plt.show()

# %%
#the highest production is in 2000 year

# %% [markdown]
# # Q5.from the above inference we get the production was highest in the year 2000, now let infer which state was having highest contribution in that year?

# %%
max_state_2000 = df[df['year']==2000]
max_state_2000
# Out:
#              state  colonies_number  yield_per_colony  production    stocks  \
# 217        Alabama            16000                78     1248000    187000
# 218        Arizona            40000                59     2360000   1322000
# 219       Arkansas            55000                93     5115000   3529000
# 220     California           440000                70    30800000  11396000
# 221       Colorado            29000                60     1740000    957000
# 222        Florida           232000               105    24360000   2923000
# 223        Georgia            55000                57     3135000    376000
# 224         Hawaii             7000               112      784000    125000
# 225          Idaho           100000                47     4700000   2679000
# 226       Illinois             8000                61      488000    146000
# 227        Indiana             8000                65      520000    286000
# ...

# %%
max_state_2000=max_state_2000.sort_values('production',ascending=False)
max_state_2000
# Out:
#              state  colonies_number  yield_per_colony  production    stocks  \
# 245    NorthDakota           290000               115    33350000  13340000
# 220     California           440000                70    30800000  11396000
# 250    SouthDakota           235000               121    28435000  12796000
# 222        Florida           232000               105    24360000   2923000
# 235      Minnesota           150000                90    13500000   3105000
# 238        Montana           148000                86    12728000   5982000
# 252          Texas           105000                79     8295000   2986000
# 258      Wisconsin            84000                90     7560000   4385000
# 234       Michigan            72000                75     5400000   2970000
# 219       Arkansas            55000                93     5115000   3529000
# 225          Idaho           100000                47     4700000   2679000
# ...

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=max_state_2000,x='state',y='production')
plt.xticks(rotation=90)
plt.show()
